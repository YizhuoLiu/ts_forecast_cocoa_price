# %%
from Train import Train
import pandas as pd
import matplotlib.pyplot as plt
import torch

# %%
data = pd.read_csv("combine.csv")

price_data = data['Price'].values.reshape(-1, 1)
temperature = data['avg_TAVG'].values.reshape(-1, 1)

price_data = price_data[:6670]
temperature = temperature[:6670]

plt.plot(price_data)
plt.show()
plt.plot(temperature)
plt.show
# Out:
# (6670, 1)
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
trainer = Train(dataset=price_data,
                dataset2=temperature,
                checkpoint=10,
                receptive_field=100,
                future_size=100,
                cuda=True,
                epochs=1000,
                n_layers_encod=4,
                n_inputs=2,
                n_outputs=[32, 64, 128, 256],
                dilation=[1, 2, 4, 8],
                stride=1,
                n_channel_decod=64,
                kernel_size=3,
                lr=1e-3,
                outf="ckpt",
                resume=False,
                sep_train_test=5500)

trainer.train()
# Out:
# Creating new networks
# Setting optimizers
# Epoch[0/1000]
# Loss_train: 5194803.5
# Loss_test : 5898389.0
# Epoch[1/1000]
# Loss_train: 5190560.5
# Loss_test : 5895132.0
# Epoch[2/1000]
# Loss_train: 5181074.5
# Loss_test : 5889575.5
# Epoch[3/1000]
# Loss_train: 5165927.5
# Loss_test : 5885564.5
# Epoch[4/1000]
# Loss_train: 5147218.5
# Loss_test : 5881269.0
# Epoch[5/1000]
# Loss_train: 5124350.5
# Loss_test : 5877193.0
# Epoch[6/1000]
# Loss_train: 5098369.5
# Loss_test : 5871566.0
# Epoch[7/1000]
# Loss_train: 5070377.5
# Loss_test : 5867663.0
# Epoch[8/1000]
# Loss_train: 5039155.5
# Loss_test : 5858996.5
# Epoch[9/1000]
# Loss_train: 5010228.5
# Loss_test : 5856633.0
# Epoch[10/1000]
# Loss_train: 4978771.0
# Loss_test : 5847128.0
# Epoch[11/1000]
# Loss_train: 4949095.0
# Loss_test : 5843052.5
# Epoch[12/1000]
# Loss_train: 4917471.0
# Loss_test : 5836030.0
# Epoch[13/1000]
# Loss_train: 4887850.0
# Loss_test : 5829822.5
# Epoch[14/1000]
# Loss_train: 4857779.0
# ...

# %%
model = torch.load("ckpt/deeptcn.pt")
# Out:
# C:\Users\ckx19\AppData\Local\Temp\ipykernel_55068\254899588.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   torch.load("ckpt/deeptcn.pt")
# ...
